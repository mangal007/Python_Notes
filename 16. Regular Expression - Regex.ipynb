# %%
#Regular expression

# A paatern defined using string which helps us to extract the information from the string

# %%
'''
.       - Any Character Except New Line
\d      - Digit (0-9)
\D      - Not a Digit (0-9)
\w      - Word Character (a-z, A-Z, 0-9, _)
\W      - Not a Word Character
\s      - Whitespace (space, tab, newline)
\S      - Not Whitespace (space, tab, newline)

\b      - Word Boundary
\B      - Not a Word Boundary
^       - Beginning of a String
$       - End of a String

[]      - Matches Characters in brackets
[^ ]    - Matches Characters NOT in brackets
|       - Either Or
( )     - Group

Quantifiers:
*       - 0 or More
+       - 1 or More
?       - 0 or One
{3}     - Exact Number
{3,4}   - Range of Numbers (Minimum, Maximum)

# %%
import re 

#it is must for regular expression

# %%
# match = matches the pattern in begining of string and return a match object

# search = matches the pattern in string and return a match object of first occurence of pattern

# findall = finds all the occcurence of the pattern and return a list of it

# finditer = find all the occurence of the pattern and return an iterator of match object.


#Note :- If we find the match object then to extract the information from match object we use group method.

# %%
# Sample file name is 'regex.txt'

# 9at Cat c9t mat bat rat hat
# abcdefghijklmnopqrstuvwxyz
# ABCEDFGHIJKLMNOPQRSTUVWXYZ
# 321-555-4321
# 1234567890
# Ha.HaHa
# MetaCharacters {Need to be escaped}
# dndwjcnlkfencnklenlkec.com
# sanchit.mangal@gmail.com
# 321-456-4567
# 354.456.3456
# 123*432*7584
# 300-899-45363
# Mr. Schafer
# Mr Smith
# Ms Davis
# Mr. T
# Mr_hello
# abhishek.gupta@gmail.com
# abhsihek@hotmail.com

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\wat')
    matches = pattern.match(content)   #Match work only if it matches from 1st object
    print(matches)
    print(matches.group())
    print(matches.span())
    print(matches.span()[0])
    print(matches.span()[1])
# Out:
# <re.Match object; span=(0, 3), match='9at'>
# 9at
# (0, 3)
# 0
# 3

# %%
import re
with open('regex.txt', 'r') as f:
    content = f.read()
for i in (re.finditer(r'\wat', content)):
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='9at'>
# <re.Match object; span=(4, 7), match='Cat'>
# <re.Match object; span=(12, 15), match='mat'>
# <re.Match object; span=(16, 19), match='bat'>
# <re.Match object; span=(20, 23), match='rat'>
# <re.Match object; span=(24, 27), match='hat'>

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'hat')
    matches = pattern.search(content)   #search look for first occurence only
    print(matches)
    print(matches.group())
    print(matches.span())
    print(matches.span()[0])
    print(matches.span()[1])
# Out:
# <re.Match object; span=(24, 27), match='hat'>
# hat
# (24, 27)
# 24
# 27

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\wat')
    matches = pattern.findall(content)   #findall give list of all matches
    print(matches)
# Out:
# ['9at', 'Cat', 'mat', 'bat', 'rat', 'hat']

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\wat')
    matches = pattern.finditer(content)   #Match work only if it matches from 1st object
for i in matches:
    print(i)
    print(i.group())
    print(i.span())
    print(i.span()[0])
    print(i.span()[1])

# %%
# "." Matches all characters except new line
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'.')
    matches = pattern.finditer(content)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 1), match='9'>
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='t'>
# <re.Match object; span=(3, 4), match=' '>
# <re.Match object; span=(4, 5), match='C'>
# <re.Match object; span=(5, 6), match='a'>
# <re.Match object; span=(6, 7), match='t'>
# <re.Match object; span=(7, 8), match=' '>
# <re.Match object; span=(8, 9), match='c'>
# <re.Match object; span=(9, 10), match='9'>
# <re.Match object; span=(10, 11), match='t'>
# <re.Match object; span=(11, 12), match=' '>
# <re.Match object; span=(12, 13), match='m'>
# <re.Match object; span=(13, 14), match='a'>
# <re.Match object; span=(14, 15), match='t'>
# <re.Match object; span=(15, 16), match=' '>
# <re.Match object; span=(16, 17), match='b'>
# <re.Match object; span=(17, 18), match='a'>
# <re.Match object; span=(18, 19), match='t'>
# <re.Match object; span=(19, 20), match=' '>
# <re.Match object; span=(20, 21), match='r'>
# <re.Match object; span=(21, 22), match='a'>
# ...

# %%
#'\s' --> all space characters
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\s')
    matches = pattern.finditer(content)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(3, 4), match=' '>
# <re.Match object; span=(7, 8), match=' '>
# <re.Match object; span=(11, 12), match=' '>
# <re.Match object; span=(15, 16), match=' '>
# <re.Match object; span=(19, 20), match=' '>
# <re.Match object; span=(23, 24), match=' '>
# <re.Match object; span=(27, 28), match='\n'>
# <re.Match object; span=(54, 55), match='\n'>
# <re.Match object; span=(81, 82), match='\n'>
# <re.Match object; span=(94, 95), match='\n'>
# <re.Match object; span=(105, 106), match='\n'>
# <re.Match object; span=(113, 114), match='\n'>
# <re.Match object; span=(128, 129), match=' '>
# <re.Match object; span=(134, 135), match=' '>
# <re.Match object; span=(137, 138), match=' '>
# <re.Match object; span=(140, 141), match=' '>
# <re.Match object; span=(149, 150), match='\n'>
# <re.Match object; span=(176, 177), match='\n'>
# <re.Match object; span=(201, 202), match='\n'>
# <re.Match object; span=(214, 215), match='\n'>
# <re.Match object; span=(227, 228), match='\n'>
# ...

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\S')
    matches = pattern.finditer(content)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 1), match='9'>
# <re.Match object; span=(1, 2), match='a'>
# <re.Match object; span=(2, 3), match='t'>
# <re.Match object; span=(4, 5), match='C'>
# <re.Match object; span=(5, 6), match='a'>
# <re.Match object; span=(6, 7), match='t'>
# <re.Match object; span=(8, 9), match='c'>
# <re.Match object; span=(9, 10), match='9'>
# <re.Match object; span=(10, 11), match='t'>
# <re.Match object; span=(12, 13), match='m'>
# <re.Match object; span=(13, 14), match='a'>
# <re.Match object; span=(14, 15), match='t'>
# <re.Match object; span=(16, 17), match='b'>
# <re.Match object; span=(17, 18), match='a'>
# <re.Match object; span=(18, 19), match='t'>
# <re.Match object; span=(20, 21), match='r'>
# <re.Match object; span=(21, 22), match='a'>
# <re.Match object; span=(22, 23), match='t'>
# <re.Match object; span=(24, 25), match='h'>
# <re.Match object; span=(25, 26), match='a'>
# <re.Match object; span=(26, 27), match='t'>
# <re.Match object; span=(28, 29), match='a'>
# ...

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\d')
    matches = pattern.finditer(content)
for i in matches:
    print(i)

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\D')
    matches = pattern.finditer(content)
for i in matches:
    print(i)

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\w')
    matches = pattern.finditer(content)
for i in matches:
    print(i)

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\W')
    matches = pattern.finditer(content)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(3, 4), match=' '>
# <re.Match object; span=(7, 8), match=' '>
# <re.Match object; span=(11, 12), match=' '>
# <re.Match object; span=(15, 16), match=' '>
# <re.Match object; span=(19, 20), match=' '>
# <re.Match object; span=(23, 24), match=' '>
# <re.Match object; span=(27, 28), match='\n'>
# <re.Match object; span=(54, 55), match='\n'>
# <re.Match object; span=(81, 82), match='\n'>
# <re.Match object; span=(85, 86), match='-'>
# <re.Match object; span=(89, 90), match='-'>
# <re.Match object; span=(94, 95), match='\n'>
# <re.Match object; span=(105, 106), match='\n'>
# <re.Match object; span=(108, 109), match='.'>
# <re.Match object; span=(113, 114), match='\n'>
# <re.Match object; span=(128, 129), match=' '>
# <re.Match object; span=(129, 130), match='{'>
# <re.Match object; span=(134, 135), match=' '>
# <re.Match object; span=(137, 138), match=' '>
# <re.Match object; span=(140, 141), match=' '>
# <re.Match object; span=(148, 149), match='}'>
# ...

# %%
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'\.')
    matches = pattern.finditer(content)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(108, 109), match='.'>
# <re.Match object; span=(172, 173), match='.'>
# <re.Match object; span=(184, 185), match='.'>
# <re.Match object; span=(197, 198), match='.'>
# <re.Match object; span=(218, 219), match='.'>
# <re.Match object; span=(222, 223), match='.'>
# <re.Match object; span=(257, 258), match='.'>
# <re.Match object; span=(287, 288), match='.'>
# <re.Match object; span=(308, 309), match='.'>
# <re.Match object; span=(320, 321), match='.'>
# <re.Match object; span=(341, 342), match='.'>

# %%
import re
string = 'cat cathole copycat cathole catchy catestrophe'
pattern = re.compile(r'\bcat')         #\bcat it means left of \b should be blank and right should be c
matches = pattern.finditer(string)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='cat'>
# <re.Match object; span=(4, 7), match='cat'>
# <re.Match object; span=(20, 23), match='cat'>
# <re.Match object; span=(28, 31), match='cat'>
# <re.Match object; span=(35, 38), match='cat'>

# %%
import re
string = 'cat cathole copycat cathole catchy catestrophe'
pattern = re.compile(r'cat\b')         #cat\b it means left of \b should be 't' and right should be blank
matches = pattern.finditer(string)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='cat'>
# <re.Match object; span=(16, 19), match='cat'>

# %%
import re
string = 'cat cathole copycat cathole catchy catestrophe'
pattern = re.compile(r'\bcat\b')         
matches = pattern.finditer(string)
for i in matches:
    print(i)
#\bcat\b it means for first \b left of \b should be blank and right should be C
#for 2nd \b left of \b should be t and right should be blank.
# Out:
# <re.Match object; span=(0, 3), match='cat'>

# %%
import re
string = 'cat cathole copycat cathole catchy catestrophe'
pattern = re.compile(r'^cat')         
matches = pattern.finditer(string)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='cat'>

# %%
import re
string = 'cat cathole copycat cathole catchy catestrophe'
pattern = re.compile(r'ophe$')         
matches = pattern.finditer(string)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(42, 46), match='ophe'>

# %%
import re
string = 'cat cathole copycat cathole catchy catestrophe'
matches = re.finditer(r'cat', string)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(0, 3), match='cat'>
# <re.Match object; span=(4, 7), match='cat'>
# <re.Match object; span=(16, 19), match='cat'>
# <re.Match object; span=(20, 23), match='cat'>
# <re.Match object; span=(28, 31), match='cat'>
# <re.Match object; span=(35, 38), match='cat'>

# %%
import re
with open('regex.txt', 'r') as f:
    content = f.read()
    pattern = re.compile(r'M(r|s|rs)\.?\s[A-z]+')
    matches = pattern.finditer(content)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(255, 266), match='Mr. Schafer'>
# <re.Match object; span=(267, 275), match='Mr Smith'>
# <re.Match object; span=(276, 284), match='Ms Davis'>
# <re.Match object; span=(285, 298), match='Mrs. Robinson'>
# <re.Match object; span=(299, 304), match='Mr. T'>

# %%
import re
def pwd_verify(pwd):
    if (re.search(r'[a-z]+', pwd)) and (len(pwd)>=8) and (re.search(r'[!#@$%^&*]+', pwd)) and (re.search(r'[A-Z]+', pwd)) and (re.search(r'[0-9]+', pwd)):
        print('valid password')
    else:
        print('password must be greater than 8 digits, Capital letter and contain special characte')

pwd = input('Enter Password ')
pwd_verify(pwd)
# Out:
# Enter Password Zaq12wsx@
# valid password

# %%
import re
def pwd_verify(pwd):
    if (re.finditer(r'\w+', pwd)) and (len(pwd)>=8) and (re.findall(r'[!#@$%^&*]+', pwd)) and (re.search(r'[A-Z]+', pwd)):
        print('valid password')
    else:
        print('password must be greater than 8 digits, Capital letter and contain special characte')

pwd = input('Enter Password')
pwd_verify(pwd)
# Out:
# Enter PasswordZaq12wsx
# password must be greater than 8 digits, Capital letter and contain special characte

# %%
import re
emails = '''
AfsanMKhan@gmail.com
afsan.khan@university.edu
afsan-321-khan@my-work.net
afsan-321-khan@my-work.abc'''

matches = re.finditer(r'[A-Za-z0-9-.]+@[a-z-]+.(com|edu|net)', emails)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(1, 21), match='AfsanMKhan@gmail.com'>
# <re.Match object; span=(22, 47), match='afsan.khan@university.edu'>
# <re.Match object; span=(48, 74), match='afsan-321-khan@my-work.net'>

# %%
import re
emails = '''
AfsanMKhan@gmail.com
afsan.khan@university.edu
afsan-321-khan@my-work.net
afsan-321-khan@my-work.abc'''

matches = re.finditer(r'[A-Za-z0-9-.]+@[a-z-]+.[^a][^b][^c]', emails)
for i in matches:
    print(i)
# Out:
# <re.Match object; span=(1, 21), match='AfsanMKhan@gmail.com'>
# <re.Match object; span=(22, 47), match='afsan.khan@university.edu'>
# <re.Match object; span=(48, 74), match='afsan-321-khan@my-work.net'>
# <re.Match object; span=(75, 100), match='afsan-321-khan@my-work.ab'>
